# %%
import pandas as pd

# Try loading each file
files = [
    "IKEA_Full_Dataset.csv",
    "IKEA_Products.csv",
    "ikea_all_products.csv",
    "ikea_all_regions.csv",
    "ikea_furniture_data.csv",
    "ikea_saudi_all_products.csv",
    "ikea_saudi_furniture_data.csv",
    "scraped_furniture_data.csv"
]

for file in files:
    try:
        df = pd.read_csv(file)
        print(f"✅ Loaded {file} successfully!")
        print(df.head(), "\n")  # Show first few rows
    except Exception as e:
        print(f"❌ Could not load {file}: {e}\n")
# Out:
# ❌ Could not load IKEA_Full_Dataset.csv: No columns to parse from file
#
# ✅ Loaded IKEA_Products.csv successfully!
#    Name  Price                                          Image URL  \
# 0   NaN    199  https://www.ikea.com/us/en/images/products/hae...
# 1   NaN    299  https://www.ikea.com/us/en/images/products/ton...
# 2   NaN     40  https://www.ikea.com/us/en/images/products/hau...
# 3   NaN    160  https://www.ikea.com/us/en/images/products/tos...
# 4   NaN    460  https://www.ikea.com/us/en/images/products/bes...
#
#                                                 Link
# 0  https://www.ikea.com/us/en/p/haegernaes-table-...
# 1  https://www.ikea.com/us/en/p/tonstad-sideboard...
# 2  https://www.ikea.com/us/en/p/hauga-chair-white...
# 3  https://www.ikea.com/us/en/p/tossberg-chair-me...
# 4  https://www.ikea.com/us/en/p/besta-storage-com...
#
# ✅ Loaded ikea_all_products.csv successfully!
#   Category Name  Price                                          Image URL  \
# 0   Chairs  NaN    199  https://www.ikea.com/us/en/images/products/hae...
# 1   Chairs  NaN    299  https://www.ikea.com/us/en/images/products/ton...
# 2   Chairs  NaN     40  https://www.ikea.com/us/en/images/products/hau...
# 3   Chairs  NaN    160  https://www.ikea.com/us/en/images/products/tos...
# 4   Chairs  NaN    460  https://www.ikea.com/us/en/images/products/bes...
#
#                                                 Link
# 0  https://www.ikea.com/us/en/p/haegernaes-table-...
# 1  https://www.ikea.com/us/en/p/tonstad-sideboard...
# 2  https://www.ikea.com/us/en/p/hauga-chair-white...
# 3  https://www.ikea.com/us/en/p/tossberg-chair-me...
# 4  https://www.ikea.com/us/en/p/besta-storage-com...
#
# ✅ Loaded ikea_all_regions.csv successfully!
#   Region Category Name Price  \
# 0    USA   Chairs  NaN   199
# 1    USA   Chairs  NaN   299
# 2    USA   Chairs  NaN    40
# 3    USA   Chairs  NaN   160
# 4    USA   Chairs  NaN   460
#
#                                            Image URL  \
# 0  https://www.ikea.com/us/en/images/products/hae...
# 1  https://www.ikea.com/us/en/images/products/ton...
# 2  https://www.ikea.com/us/en/images/products/hau...
# 3  https://www.ikea.com/us/en/images/products/tos...
# 4  https://www.ikea.com/us/en/images/products/bes...
#
#                                                 Link
# 0  https://www.ikea.com/us/en/p/haegernaes-table-...
# 1  https://www.ikea.com/us/en/p/tonstad-sideboard...
# 2  https://www.ikea.com/us/en/p/hauga-chair-white...
# 3  https://www.ikea.com/us/en/p/tossberg-chair-me...
# 4  https://www.ikea.com/us/en/p/besta-storage-com...
#
# ✅ Loaded ikea_furniture_data.csv successfully!
# Empty DataFrame
# Columns: [Website, Title, Price, Image URL, Product Link]
# Index: []
#
# ✅ Loaded ikea_saudi_all_products.csv successfully!
# Empty DataFrame
# Columns: [Website, Title, Price, Image URL, Product Link, Description, Dimensions]
# Index: []
#
# ✅ Loaded ikea_saudi_furniture_data.csv successfully!
#              Website  Title  Price  \
# 0  IKEA Saudi Arabia    NaN    649
# 1  IKEA Saudi Arabia    NaN  1,595
# 2  IKEA Saudi Arabia    NaN  2,795
# 3  IKEA Saudi Arabia    NaN    299
# 4  IKEA Saudi Arabia    NaN    895
#
#                                            Image URL  Product Link
# 0  https://www.ikea.com/sa/en/images/products/glo...           NaN
# 1  https://www.ikea.com/sa/en/images/products/ael...           NaN
# 2  https://www.ikea.com/sa/en/images/products/aep...           NaN
# 3  https://www.ikea.com/sa/en/images/products/nei...           NaN
# 4  https://www.ikea.com/sa/en/images/products/tae...           NaN
#
# ✅ Loaded scraped_furniture_data.csv successfully!
# Empty DataFrame
# Columns: [Website, Title, Price, Image URL]
# Index: []

# %%
import pandas as pd

# Load datasets
df_products = pd.read_csv("IKEA_Products.csv")
df_regions = pd.read_csv("ikea_all_regions.csv")

# Check first few rows
print(df_products.head())
print(df_regions.head())

# Merge on 'Link' column (assuming this column uniquely identifies products)
df_merged = df_regions.merge(df_products, on="Link", how="left")

# Save the cleaned dataset
df_merged.to_csv("ikea_cleaned_data.csv", index=False)
print("✅ Cleaned dataset saved as ikea_cleaned_data.csv")
# Out:
#    Name  Price                                          Image URL  \
# 0   NaN    199  https://www.ikea.com/us/en/images/products/hae...
# 1   NaN    299  https://www.ikea.com/us/en/images/products/ton...
# 2   NaN     40  https://www.ikea.com/us/en/images/products/hau...
# 3   NaN    160  https://www.ikea.com/us/en/images/products/tos...
# 4   NaN    460  https://www.ikea.com/us/en/images/products/bes...
#
#                                                 Link
# 0  https://www.ikea.com/us/en/p/haegernaes-table-...
# 1  https://www.ikea.com/us/en/p/tonstad-sideboard...
# 2  https://www.ikea.com/us/en/p/hauga-chair-white...
# 3  https://www.ikea.com/us/en/p/tossberg-chair-me...
# 4  https://www.ikea.com/us/en/p/besta-storage-com...
#   Region Category Name Price  \
# 0    USA   Chairs  NaN   199
# 1    USA   Chairs  NaN   299
# 2    USA   Chairs  NaN    40
# 3    USA   Chairs  NaN   160
# 4    USA   Chairs  NaN   460
#
#                                            Image URL  \
# 0  https://www.ikea.com/us/en/images/products/hae...
# 1  https://www.ikea.com/us/en/images/products/ton...
# 2  https://www.ikea.com/us/en/images/products/hau...
# 3  https://www.ikea.com/us/en/images/products/tos...
# 4  https://www.ikea.com/us/en/images/products/bes...
#
#                                                 Link
# 0  https://www.ikea.com/us/en/p/haegernaes-table-...
# 1  https://www.ikea.com/us/en/p/tonstad-sideboard...
# 2  https://www.ikea.com/us/en/p/hauga-chair-white...
# 3  https://www.ikea.com/us/en/p/tossberg-chair-me...
# 4  https://www.ikea.com/us/en/p/besta-storage-com...
# ✅ Cleaned dataset saved as ikea_cleaned_data.csv

# %%
print(df_merged.isnull().sum())  # Count missing values per column
# Out:
# Region           0
# Category         0
# Name_x         355
# Price_x          0
# Image URL_x      0
# Link             0
# Name_y         388
# Price_y        368
# Image URL_y    368
# dtype: int64

# %%
import pandas as pd

# Load merged dataset
df = pd.read_csv("ikea_cleaned_data.csv")

# Fill missing product names
df["Name_x"].fillna(df["Name_y"], inplace=True)

# Fill missing prices
df["Price_x"].fillna(df["Price_y"], inplace=True)

# Fill missing images
df["Image URL_x"].fillna(df["Image URL_y"], inplace=True)

# Drop redundant columns
df_cleaned = df.drop(columns=["Name_y", "Price_y", "Image URL_y"])

# Rename columns for clarity
df_cleaned.rename(columns={"Name_x": "Product Name", "Price_x": "Price", "Image URL_x": "Image URL"}, inplace=True)

# Save the cleaned dataset
df_cleaned.to_csv("ikea_final_data.csv", index=False)
print("✅ Cleaned dataset saved as ikea_final_data.csv")
# Out:
# ✅ Cleaned dataset saved as ikea_final_data.csv
# /var/folders/1z/nx4fc3l1091f0k_ztz4rlzlm0000gn/T/ipykernel_32680/2841117610.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name_x"].fillna(df["Name_y"], inplace=True)
# /var/folders/1z/nx4fc3l1091f0k_ztz4rlzlm0000gn/T/ipykernel_32680/2841117610.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price_x"].fillna(df["Price_y"], inplace=True)
# /var/folders/1z/nx4fc3l1091f0k_ztz4rlzlm0000gn/T/ipykernel_32680/2841117610.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Image URL_x"].fillna(df["Image URL_y"], inplace=True)

# %%
import pandas as pd

# Load merged dataset
df = pd.read_csv("ikea_cleaned_data.csv")

# Correct way to fill missing values
df["Name_x"] = df["Name_x"].fillna(df["Name_y"])
df["Price_x"] = df["Price_x"].fillna(df["Price_y"])
df["Image URL_x"] = df["Image URL_x"].fillna(df["Image URL_y"])

# Drop redundant columns
df_cleaned = df.drop(columns=["Name_y", "Price_y", "Image URL_y"])

# Rename columns for clarity
df_cleaned.rename(columns={"Name_x": "Product Name", "Price_x": "Price", "Image URL_x": "Image URL"}, inplace=True)

# Save the cleaned dataset
df_cleaned.to_csv("ikea_final_data.csv", index=False)
print("✅ Cleaned dataset saved as ikea_final_data.csv")
# Out:
# ✅ Cleaned dataset saved as ikea_final_data.csv

# %%
print(df_cleaned.isnull().sum())
# Out:
# Region            0
# Category          0
# Product Name    355
# Price             0
# Image URL         0
# Link              0
# dtype: int64

# %%
import pandas as pd
import time
from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# ✅ Load dataset
df = pd.read_csv("ikea_final_data.csv")

# ✅ Filter rows where product names are missing
missing_names = df[df["Product Name"].isnull()]

# ✅ Set up Selenium (Headless Chrome)
chrome_options = Options()
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--disable-dev-shm-usage")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# ✅ Function to scrape product names from IKEA
def get_product_name(url):
    try:
        driver.get(url)
        time.sleep(5)  # Wait for page to load
        name = driver.find_element(By.CLASS_NAME, "pip-header-section__title").text.strip()
        return name
    except:
        return None

# ✅ Scrape missing product names
for index, row in missing_names.iterrows():
    product_name = get_product_name(row["Link"])
    if product_name:
        df.at[index, "Product Name"] = product_name
    time.sleep(2)  # Avoid getting blocked

# ✅ Close Selenium
driver.quit()

# ✅ Save updated dataset
df.to_csv("ikea_final_fixed.csv", index=False)
print("✅ Missing product names scraped and saved as ikea_final_fixed.csv")
# Out:
# ✅ Missing product names scraped and saved as ikea_final_fixed.csv

# %%
print(df.isnull().sum())
# Out:
# Region            0
# Category          0
# Product Name    355
# Price             0
# Image URL         0
# Link              0
# dtype: int64

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# ✅ Load dataset
df = pd.read_csv("ikea_final_data.csv")

# ✅ Filter rows where product names are missing
missing_names = df[df["Product Name"].isnull()]

# ✅ Set up Selenium (Headless Chrome)
chrome_options = Options()
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--disable-dev-shm-usage")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# ✅ Function to scrape product names from IKEA
def get_product_name(url):
    try:
        print(f"🔄 Fetching: {url}")
        driver.get(url)
        time.sleep(7)  # Wait for page to fully load

        # Debug: Print first 500 characters of page source
        print(driver.page_source[:500])

        # ✅ Try different selectors
        try:
            name = driver.find_element(By.CLASS_NAME, "pip-header-section__title").text.strip()
        except:
            name = driver.find_element(By.CSS_SELECTOR, "h1.pip-header-section__title").text.strip()

        print(f"✅ Product Name Found: {name}")
        return name
    except Exception as e:
        print(f"❌ Failed to get name for {url}: {e}")
        return None

# ✅ Scrape missing product names
for index, row in missing_names.iterrows():
    product_name = get_product_name(row["Link"])
    if product_name:
        df.at[index, "Product Name"] = product_name
    time.sleep(3)  # Avoid blocking

# ✅ Close Selenium
driver.quit()

# ✅ Save updated dataset
df.to_csv("ikea_final_fixed.csv", index=False)
print("✅ Missing product names scraped and saved as ikea_final_fixed.csv")
# Out:
# 🔄 Fetching: https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script async="" src="https://s.pinimg.com/ct/lib/main.8821a9da.js"></script><script type="text/javascript" async=""
# ❌ Failed to get name for https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/tonstad-sideboard-off-white-00510006/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/tonstad-sideboard-off-white-00510006/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/hauga-chair-white-10576718/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/hauga-chair-white-10576718/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/tossberg-chair-metal-black-gunnared-dark-gray-80582645/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/tossberg-chair-metal-black-gunnared-dark-gray-80582645/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/besta-storage-combination-with-doors-white-hammarsmed-stubbarp-anthracite-s29569341/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/besta-storage-combination-with-doors-white-hammarsmed-stubbarp-anthracite-s29569341/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-white-80275887/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-white-80275887/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/antilop-high-chair-with-tray-white-silver-color-s89228434/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/antilop-high-chair-with-tray-white-silver-color-s89228434/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-black-brown-20275885/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-black-brown-20275885/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-white-stained-oak-effect-00324518/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-white-stained-oak-effect-00324518/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-with-4-inserts-white-s59278307/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-with-4-inserts-white-s59278307/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/holmerud-side-table-oak-effect-40541421/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/holmerud-side-table-oak-effect-40541421/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/besta-storage-combination-with-doors-white-stained-oak-effect-lappviken-stubbarp-white-stained-oak-effect-s49139722/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/besta-storage-combination-with-doors-white-stained-oak-effect-lappviken-stubbarp-white-stained-oak-effect-s49139722/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-high-gloss-white-10305741/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-high-gloss-white-10305741/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/smastad-bench-with-toy-storage-white-white-s19389152/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/smastad-bench-with-toy-storage-white-white-s19389152/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/flisat-childrens-table-50298418/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/flisat-childrens-table-50298418/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/kallax-shelf-unit-with-4-inserts-white-stained-oak-effect-s29197572/
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" d
# ❌ Failed to get name for https://www.ikea.com/us/en/p/kallax-shelf-unit-with-4-inserts-white-stained-oak-effect-s29197572/: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.pip-header-section__title"}
#   (Session info: chrome=133.0.6943.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000102f402d4 cxxbridge1$str$ptr + 2739836
# 1   chromedriver                        0x0000000102f38934 cxxbridge1$str$ptr + 2708700
# 2   chromedriver                        0x0000000102a99f90 cxxbridge1$string$len + 93360
# 3   chromedriver                        0x0000000102ae0de4 cxxbridge1$string$len + 383748
# 4   chromedriver                        0x0000000102b21e80 cxxbridge1$string$len + 650144
# 5   chromedriver                        0x0000000102ad5060 cxxbridge1$string$len + 335232
# 6   chromedriver                        0x0000000102f08c38 cxxbridge1$str$ptr + 2512864
# 7   chromedriver                        0x0000000102f0bf58 cxxbridge1$str$ptr + 2525952
# 8   chromedriver                        0x0000000102eee578 cxxbridge1$str$ptr + 2404640
# 9   chromedriver                        0x0000000102f0c818 cxxbridge1$str$ptr + 2528192
# 10  chromedriver                        0x0000000102edef2c cxxbridge1$str$ptr + 2341588
# 11  chromedriver                        0x0000000102f28a60 cxxbridge1$str$ptr + 2643464
# 12  chromedriver                        0x0000000102f28be8 cxxbridge1$str$ptr + 2643856
# 13  chromedriver                        0x0000000102f385a8 cxxbridge1$str$ptr + 2707792
# 14  libsystem_pthread.dylib             0x00000001987cc2e4 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x00000001987c70fc thread_start + 8
#
# 🔄 Fetching: https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# ✅ Set up Selenium
chrome_options = Options()
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--disable-dev-shm-usage")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# ✅ IKEA Product Page (Use any product link)
url = "https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/"

# ✅ Load Page
driver.get(url)
time.sleep(5)

# ✅ Print Full Page Source (Check for Product Name Element)
print(driver.page_source)

# ✅ Close Selenium
driver.quit()
# Out:
# <html lang="en-US" dir="ltr" class="js-focus-visible js" data-js-focus-visible=""><head data-optly-286029aecfdd4012a678eb19bd35e0a6="" data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd=""><script src="https://ct.pinterest.com/static/ct/token_create.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_9d76dc36.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTIwNTdiZjNmMA.js" data-id="CR6808BC77UBVEOEFGAG"></script><script async="" src="https://s.pinimg.com/ct/lib/main.8821a9da.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=DC-6739053&amp;l=mtDataLayer&amp;cx=c&amp;gtm=45be52q0v898469414za200&amp;tag_exp=101732282~101732284~102067808~102482433~102539968~102558064~102587591~102605417~102640600~102658453~102717422~102732003"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=CR6808BC77UBVEOEFGAG&amp;lib=ttq"></script><script async="" src="https://s.pinimg.com/ct/core.js"></script><script src="https://connect.facebook.net/signals/config/3465423686912116?v=2.9.184&amp;r=stable&amp;domain=www.ikea.com&amp;hme=93c44828b638838a88daf3a14a90ff297f7fc4ade758f21de5500c9f17542765&amp;ex_m=70%2C122%2C107%2C111%2C61%2C4%2C100%2C69%2C16%2C97%2C89%2C51%2C54%2C173%2C176%2C188%2C184%2C185%2C187%2C29%2C101%2C53%2C77%2C186%2C168%2C171%2C181%2C182%2C189%2C132%2C41%2C194%2C191%2C192%2C34%2C144%2C15%2C50%2C198%2C197%2C134%2C18%2C40%2C1%2C43%2C65%2C66%2C67%2C71%2C93%2C17%2C14%2C96%2C92%2C91%2C108%2C52%2C110%2C39%2C109%2C30%2C94%2C26%2C169%2C172%2C141%2C86%2C56%2C84%2C33%2C73%2C0%2C95%2C32%2C28%2C82%2C83%2C88%2C47%2C46%2C87%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C57%2C62%2C64%2C75%2C102%2C27%2C76%2C9%2C8%2C80%2C48%2C21%2C104%2C103%2C105%2C98%2C10%2C20%2C3%2C38%2C74%2C19%2C5%2C90%2C81%2C44%2C35%2C85%2C2%2C36%2C63%2C42%2C106%2C45%2C79%2C68%2C112%2C60%2C59%2C31%2C99%2C58%2C55%2C49%2C78%2C72%2C24%2C113" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" defer="" async="" src="https://collector-48219.us.tvsquared.com/tv2track.js"></script><script src="https://www.redditstatic.com/ads/pixel.js" async=""></script><script src="https://s.yimg.com/wi/ytc.js" async=""></script><script src="//bat.bing.com/bat.js" async=""></script><script type="text/javascript" async="" src="https://cdn-pci.optimizely.com/js/geo4.js"></script><meta charset="utf-8"><title>HÄGERNÄS table and 4 chairs, antique stain pine - IKEA</title><meta name="description" content="HÄGERNÄS table and 4 chairs, antique stain pine Solid pine is a natural material that ages beautifully and acquires its own unique character over time. Easy to bring home since the whole dining set is packed in one box."><meta property="og:description" content="HÄGERNÄS table and 4 chairs, antique stain pine Solid pine is a natural material that ages beautifully and acquires its own unique character over time. Easy to bring home since the whole dining set is packed in one box."><meta name="keywords" content="HÄGERNÄS, Table and 4 chairs"><meta name="og:description" content="HÄGERNÄS table and 4 chairs, antique stain pine Solid pine is a natural material that ages beautifully and acquires its own unique character over time. Easy to bring home since the whole dining set is packed in one box."><meta name="og:title" content="HÄGERNÄS table and 4 chairs, antique stain pine"><meta name="robots" content="index, follow"><meta property="og:title" content="HÄGERNÄS table and 4 chairs, antique stain pine - IKEA"><meta property="og:type" content="product"><meta property="og:image" content="https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1350925_pe951817_s5.jpg"><meta property="og:url" content="https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-705759 ...
#   <meta name="viewport" content="width=device-width, initial-scale=1"><link rel="stylesheet" href="https://www.ikea.com/us/en/products/stylesheets/pip-styles.206b045bab97ba93bcce.css"><!-- 2025-02-26T19:38:05.978Z, Navigera 5ce51d025d0731854912b87c7b31556c29961ab1 -->
#     <link rel="stylesheet" id="nav-styles" data-opti-web="true" data-opti-default="true" href="https://www.ikea.com/us/en/header-footer/styles/main.7dbf7aad1668613f2b47.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/localisationPicker.4d31c777df499a341e5e.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/postalCodePicker.8e2dab8c426bfa0aa1fa.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/storePicker.c1cd86e3be5d7645af60.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/tabsNavigation.fbe3ecafb035a7151085.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/mobileMenu.79870c7a91216315f513.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/marketPicker.dd0a8af5cb4388040911.css">
#   <link rel="stylesheet" href="https://www.ikea.com/us/en/header-footer/styles/bouncyFooter.d33db284a182eb135270.css">
#   <link rel="stylesheet" href="https://www.ikea.com/global/assets/fonts/en/fonts.fa002b0f.css">
#     <script async="" src="//js.pulseinsights.com/surveys.js"></script><script src="https://www.ikea.com/us/en/cookieconsent/scripts/cookieconsent-onetrust-js.js?v=m4toev9n"></script><link rel="stylesheet" type="text/css" href="https://www.ikea.com/us/en/cookieconsent/styles/cookieconsent-onetrust-css-v2.css?v=m4toev9n"><script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-domain-script="4244663a-4a15-47ea-a1da-49d65bf37f90" data-document-language="true" data-script-vendor="onetrust" type="text/javascript"></script>
#     <script src="https://www.ikea.com/us/en/ikea-abtesting/scripts/ikea-abtesting-cookieconsent-optimizely.m7kdet3k.js"></script><script src="https://www.ikea.com/us/en/ikea-abtesting/scripts/ikea-abtesting-fragment-optimizely.m7kdet3k.js"></script><script src="https://www.ikea.com/us/en/ikea-abtesting/scripts/ikea-abtesting-default-datafile.m7kdet3k.js"></script>
#     <!-- Search Box Styles: 2025-02-28 10:45:12 CET 19af4ec048880f7db847ba521b5cd9a35b85487f -->
# <link rel="preconnect" href="https://sik.search.blue.cdtapps.com" crossorigin="">
# <link rel="stylesheet" href="https://www.ikea.com/us/en/search/box.46f38776.css">
# <!-- /Search Box Styles -->
#
#     <!-- RecommendationsStyle: version: 64f0c61f4b68ec3e52cc749b441be4c6c5104b34, site-folder: us/en --><link rel="stylesheet" href="https://www.ikea.com/us/en/recommendations/panels/css/main.70e91b67.css"><!-- /RecommendationsStyle -->
#     <!-- gitVersion: 20250302T005107-b33dde84, siteFolder: us/en -->
# <link rel="stylesheet" href="https://www.ikea.com/us/en/insp-feed/content-gallery-app/feed.e4d2f261.css">
#
#     <link href="https://www.ikea.com/us/en/loyalty/loyalty-modal.f8545d.css" rel="stylesheet">
#     <script src="https://www.ikea.com/ext/optimizelyjs/s/united_states_web.js" async=""></script>
#     <link rel="stylesheet" crossorigin="" href="https://www.ikea.com/us/en/nudge/asset.DzJSnh8M.css">
#
#
#   <link rel="shortcut icon" sizes="any" href="https://www.ikea.com/us/en/static/favicon.838d8a3778e4d716eb72.ico">
#   <link rel="icon" type="image/svg+xml" href="https://www.ikea.com/global/assets/logos/brand/ikea.svg">
#   <meta name="robots" content="max-image-preview:large">
#
#
# <script data-type="utag-data">var utag_data = {"category":"36212","category_local":"Dining sets up to 4 seats","currency_code":"USD","event_array":["product_view"],"hfb_name":"Dining","hfb_no":"08","pa_name":"Tables","pa_no":"0811","page_name":"product information page\u003eprodview\u003e70575947","page_type":"product information page","pip_per_visit":"+1","pra_name":"Dining tables","pra_no":"081","price":["199.99"],"product_collections":"no collections","product_ids":["70575947"],"product_images_no":"6","product_item_names":["hägernäs table and 4 chairs antique stain pine"],"product_names":["hägernäs"],"product_prices":["199.99"],"product_series":"no series","product_type":"ART","product_variant":"Antique stain pine","product_vats":["0.00"],"prodview_type":"PIP","site_platform":"m2","site_section":"product information page","subproducts":"","tax":["0.00"],"visit_country":"us","visit_language":"en"}</script><script type="text/javascript">window["optimizelyDatafile"] = {"accountId":"11701662245","projectId":"14982271315","revision":"2495","attributes":[{"id":"14987010317","key":"viewport"},{"id":"17712750424","key":"country"},{"id":"17726200402","key":"environment"},{"id":"17739372013","key":"add_to_cart_src"},{"id":"17745160399","key":"browser"},{"id":"17745420132","key":"device"},{"id":"22160840644","key":"quantity"},{"id":"22189611288","key":"upsellType"},{"id":"22387744512","key":"is_entrance_visit"},{"id":"22608820105","key":"pip-environment"},{"id":"22614730109","key":"pip-locale"},{"id":"22620741960","key":"pip_to_pip_src"},{"id":"22625690096","key":"pip-country"},{"id":"22635940083","key":"pip-device"},{"id":"22643200079","key":"pip-browser"},{"id":"22703986854","key":"pip-hfb-name"},{"id":"22706894209","key":"pip-product-area-name"},{"id":"27311240494","key":"pip-logged-in-user"},{"id":"27436230048","key":"deviceVendor"},{"id":"27436600029","key":"isLoggedIn"},{"id":"27440290031","key":"deviceType"},{"id":"27442070031","key":"market"},{"id":"27442410021","key":"language"},{"id":"27453190049","key":"feedMarket"},{"id":"27469310032","key":"os"},{"id":"29232780069","key":"pip-language"},{"id":"4897037909491712","key":"isEntranceVisit"},{"id":"6022937816334336","key":"locale"}],"audiences":[{"id":"4575091086852096","conditions":"[\"and\", [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"deviceType\", \"type\": \"custom_attribute\", \"value\": \"mobile\"}]]]","name":"Mobile users"},{"id":"4611451835383808","conditions":"[\"and\", [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"feedMarket\", \"type\": \"custom_attribute\", \"value\": \"en-US\"}]]]","name":"US market english"},{"id":"5133089035255808","conditions":"[\"and\", [\"or\", [\"not\", [\"or\", {\"match\": \"exact\", \"name\": \"feedMarket\", \"type\": \"custom_attribute\", \"value\": \"en-US\"}]]], [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"language\", \"type\": \"custom_attribute\", \"value\": \"en\"}]]]","name":"English and Not US market"},{"id":"5259782492258304","conditions":"[\"and\", [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"no\"}]]]","name":"Experiment test"},{"id":"5861970755190784","conditions":"[\"and\", [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"at\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"au\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"be\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"ca\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"ch\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"dk\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": \"no\"}, {\"match\": \"exact\", \"name\": \"market\", \"type\": \"custom_attribute\", \"value\": ...
#     {
#       margin: 15px !important;
#     }
#     </style><style data-optly-286029aecfdd4012a678eb19bd35e0a6="">.pip-price-module__usdh-discount {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
# 	.pip-temp-commercial-message {
#     font-size: 12px;
#     background: white;
#     padding: 0;
#     border: none;
#     color: RGB(204, 0, 1);
#     text-transform: none;
# 	}
#
#   .pip-price-module__usdh-discount--family {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
#   .pip-price-module__usdh-discount-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background: RGB(204, 0, 1);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .pip-price-module__usdh-discount-family-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background:  rgb(0, 124, 193);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .pip-price-module__usdh-discount-line2 {
#     display: block;
#     font-size: 12px;
#     color: RGB(204,0,1);
#   }
#
#   .pip-price-module__usdh-discount-family-line2 {
#     display: block;
#     font-size: 12px;
#     color: rgb(0, 124, 193);
#   }
#
#
#   .plp-price-module__usdh-discount {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
# 	.plp-temp-commercial-message__title{
#     font-size: 12px;
#     text-transform: none;
#     color: RGB(204,0,1);
# 	}
#
#   .plp-price-module__usdh-discount--family {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
#   .plp-price-module__usdh-discount-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background: RGB(204, 0, 1);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .plp-price-module__usdh-discount-family-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background:  rgb(0, 124, 193);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .plp-price-module__usdh-discount-line2 {
#     display: block;
#     font-size: 12px;
#     color: RGB(204,0,1);
#   }
#
#   .plp-price-module__usdh-discount-family-line2 {
#     display: block;
#     font-size: 12px;
#     color: rgb(0, 124, 193);
#   }
#
# 	.plp-text-usdh-family{
#     color: white;
#     background: rgb(0, 124, 193);
# 	}
#
# 	.plp-text-usdh {
#     color: white;
#     background: RGB(204,0,1);
# 	}
#
#   .pip-temp-commercial-message--tro .pip-temp-commercial-message__title {
#     color: white;
#     background: rgb(204, 0, 1);
#     padding: 3px;
#     padding-left: 7px;
# 		padding-right: 7px;
#     position: absolute;
#     font-size: 14px;
#   }
#
#   .pip-temp-commercial-message--family .pip-temp-commercial-message__title {
#     color: white;
#     background: rgb(0, 124, 193);
#     padding: 3px;
#     font-size: 14px;
#   }</style><style data-optly-5d71a0e8-349f-4cb8-8340-353245be15fd="">.pip-price-module__usdh-discount {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
# 	.pip-temp-commercial-message {
#     font-size: 12px;
#     background: white;
#     padding: 0;
#     border: none;
#     color: RGB(204, 0, 1);
#     text-transform: none;
# 	}
#
#   .pip-price-module__usdh-discount--family {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
#   .pip-price-module__usdh-discount-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background: RGB(204, 0, 1);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .pip-price-module__usdh-discount-family-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background:  rgb(0, 124, 193);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .pip-price-module__usdh-discount-line2 {
#     display: block;
#     font-size: 12px;
#     color: RGB(204,0,1);
#   }
#
#   .pip-price-module__usdh-discount-family-line2 {
#     display: block;
#     font-size: 12px;
#     color: rgb(0, 124, 193);
#   }
#
#
#   .plp-price-module__usdh-discount {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
# 	.plp-temp-commercial-message__title{
#     font-size: 12px;
#     text-transform: none;
#     color: RGB(204,0,1);
# 	}
#
#   .plp-price-module__usdh-discount--family {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
#     width: auto;
#   }
#
#   .plp-price-module__usdh-discount-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background: RGB(204, 0, 1);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .plp-price-module__usdh-discount-family-line1 {
#     display: block;
#     font-size: 12px;
#     line-height: 1;
#     color: white;
#     background:  rgb(0, 124, 193);
#     margin-bottom: 5px;
#     padding: 3px;
#     white-space: nowrap;
#     text-align: center;
#     width: 80%
#   }
#
#   .plp-price-module__usdh-discount-line2 {
#     display: block;
#     font-size: 12px;
#     color: RGB(204,0,1);
#   }
#
#   .plp-price-module__usdh-discount-family-line2 {
#     display: block;
#     font-size: 12px;
#     color: rgb(0, 124, 193);
#   }
#
# 	.plp-text-usdh-family{
#     color: white;
#     background: rgb(0, 124, 193);
# 	}
#
# 	.plp-text-usdh {
#     color: white;
#     background: RGB(204,0,1);
# 	}
#
#   .pip-temp-commercial-message--tro .pip-temp-commercial-message__title {
#     color: white;
#     background: rgb(204, 0, 1);
#     padding: 3px;
#     padding-left: 7px;
# 		padding-right: 7px;
#     position: absolute;
#     font-size: 14px;
#   }
#
#   .pip-temp-commercial-message--family .pip-temp-commercial-message__title {
#     color: white;
#     background: rgb(0, 124, 193);
#     padding: 3px;
#     font-size: 14px;
#   }</style><link rel="modulepreload" as="script" crossorigin="" href="https://www.ikea.com/us/en/shoppingcart/agent/index-B3dDMYWe.js"><link rel="modulepreload" as="script" crossorigin="" href="https://www.ikea.com/us/en/shoppingcart/agent/_commonjsHelpers-Cpj98o6Y.js"><script type="text/javascript" src="https://web-api.ikea.com/cschatbot/web-engine//engine.js"></script><link rel="stylesheet" type="text/css" href="https://www.ikea.com/us/en/recommendations/panels/css/rec-add-to-cart.d16d50bd.css"><link rel="stylesheet" type="text/css" href="https://www.ikea.com/us/en/recommendations/panels/css/rec-init-mount-panels.3f9246e4.css"><link rel="modulepreload" as="script" crossorigin="" href="https://www.ikea.com/global/assets/rotera/index-Dx5P4m3D.js"><link rel="modulepreload" as="script" crossorigin="" href="https://www.ikea.com/global/assets/rotera/index-BHBtcb7W.js"><link rel="stylesheet" crossorigin="" href="https://www.ikea.com/global/assets/rotera/index-ww0wiGen.css"><script src="https://cdn.cookielaw.org/scripttemplates/202411.2.0/otBannerSdk.js" async="" type="text/javascript"></script><style id="onetrust-style">#onetrust-banner-sdk .onetrust-vendors-list-handler{cursor:pointer;color:#1f96db;font-size:inherit;font-weight:bold;text-decoration:none;margin-left:5px}#onetrust-banner-sdk .onetrust-vendors-list-handler:hover{color:#1f96db}#onetrust-banner-sdk:focus{outline:2px solid #000;outline-offset:-2px}#onetrust-banner-sdk a:focus{outline:2px solid #000}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{outline-offset:1px}#onetrust-banner-sdk.ot-bnr-w-logo .ot-bnr-logo{height:64px;width:64px}#onetrust-banner-sdk .ot-tcf2-vendor-count.ot-text-bold{font-weight:bold}#onetrust-banner-sdk .ot-close-icon,#onetrust-pc-sdk .ot-close-icon,#ot-sync-ntfy .ot-close-icon{background-size:contain;background-repeat:no-repeat;background-position:center;height:12px;width:12px}#onetrust-banner-sdk .powered-by-logo,#onetrust-banner-sdk .ot-pc-footer-logo a,#onetrust-pc-sdk .powered-by-logo,#onetrust-pc-sdk .ot-pc-footer-logo a,#ot-sync-ntfy .powered-by-logo,#ot-sync-ntfy .ot-pc-footer-logo a{background-size:contain;background-repeat:no-repeat;background-position:center;height:25px;width:152px;display:block;text-decoration:none;font-size:.75em}#onetrust-banner-sdk .powered-by-logo:hover,#onetrust-banner-sdk .ot-pc-footer-logo a:hover,#onetrust-pc-sdk .powered-by-logo:hover,#onetrust-pc-sdk .ot-pc-footer-logo a:hover,#ot-sync-ntfy .powered-by-logo:hover,#ot-sync-ntfy .ot-pc-footer-logo a:hover{color:#565656}#onetrust-banner-sdk h3 *,#onetrust-banner-sdk h4 *,#onetrust-banner-sdk h6 *,#onetrust-banner-sdk button *,#onetrust-banner-sdk a[data-parent-id] *,#onetrust-pc-sdk h3 *,#onetrust-pc-sdk h4 *,#onetrust-pc-sdk h6 *,#onetrust-pc-sdk button *,#onetrust-pc-sdk a[data-parent-id] *,#ot-sync-ntfy h3 *,#ot-sync-ntfy h4 *,#ot-sync-ntfy h6 *,#ot-sync-ntfy button *,#ot-sync-ntfy a[data-parent-id] *{font-size:inherit;font-weight:inherit;color:inherit}#onetrust-banner-sdk .ot-hide,#onetrust-pc-sdk .ot-hide,#ot-sync-ntfy .ot-hide{display:none !important}#onetrust-banner-sdk button.ot-link-btn:hover,#onetrust-pc-sdk button.ot-link-btn:hover,#ot-sync-ntfy button.ot-link-btn:hover{text-decoration:underline;opacity:1}#onetrust-pc-sdk .ot-sdk-row .ot-sdk-column{padding:0}#onetrust-pc-sdk .ot-sdk-container{padding-right:0}#onetrust-pc-sdk .ot-sdk-row{flex-direction:initial;width:100%}#onetrust-pc-sdk [type=checkbox]:checked,#onetrust-pc-sdk [type=checkbox]:not(:checked){pointer-events:initial}#onetrust-pc-sdk [type=checkbox]:disabled+label::before,#onetrust-pc-sdk [type=checkbox]:disabled+label:after,#onetrust-pc-sdk [type=checkbox]:disabled+label{pointer-events:none;opacity:.8}#onetrust-pc-sdk #vendor-list-content{transform:translate3d(0, 0, 0)}#onetrust-pc-sdk li input[type=checkbox]{z-index:1}#onetrust-pc-sdk li .ot-checkbox label{z-index:2}#onetrust-pc-sdk li .ot-c ...
#         #onetrust-consent-sdk #onetrust-banner-sdk {background-color: #FFFFFF;}
#             #onetrust-consent-sdk #onetrust-policy-title,
#                     #onetrust-consent-sdk #onetrust-policy-text,
#                     #onetrust-consent-sdk .ot-b-addl-desc,
#                     #onetrust-consent-sdk .ot-dpd-desc,
#                     #onetrust-consent-sdk .ot-dpd-title,
#                     #onetrust-consent-sdk #onetrust-policy-text *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk .ot-dpd-desc *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk #onetrust-banner-sdk #banner-options *,
#                     #onetrust-banner-sdk .ot-cat-header,
#                     #onetrust-banner-sdk .ot-optout-signal
#                     {
#                         color: #696969;
#                     }
#             #onetrust-consent-sdk #onetrust-banner-sdk .banner-option-details {
#                     background-color: #E9E9E9;}
#              #onetrust-consent-sdk #onetrust-banner-sdk a[href],
#                     #onetrust-consent-sdk #onetrust-banner-sdk a[href] font,
#                     #onetrust-consent-sdk #onetrust-banner-sdk .ot-link-btn
#                         {
#                             color: #3860BE;
#                         }#onetrust-consent-sdk #onetrust-accept-btn-handler,
#                          #onetrust-banner-sdk #onetrust-reject-all-handler {
#                             background-color: #68b631;border-color: #68b631;
#                 color: #FFFFFF;
#             }
#             #onetrust-consent-sdk #onetrust-banner-sdk *:focus,
#             #onetrust-consent-sdk #onetrust-banner-sdk:focus {
#                outline-color: #000000;
#                outline-width: 1px;
#             }
#             #onetrust-consent-sdk #onetrust-pc-btn-handler,
#             #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link {
#                 color: #6CC04A; border-color: #6CC04A;
#                 background-color:
#                 #FFFFFF;
#             }.ot-sdk-cookie-policy{font-family:inherit;font-size:16px}.ot-sdk-cookie-policy.otRelFont{font-size:1rem}.ot-sdk-cookie-policy h3,.ot-sdk-cookie-policy h4,.ot-sdk-cookie-policy h6,.ot-sdk-cookie-policy p,.ot-sdk-cookie-policy li,.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy th,.ot-sdk-cookie-policy #cookie-policy-description,.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}.ot-sdk-cookie-policy h4{font-size:1.2em}.ot-sdk-cookie-policy h6{font-size:1em;margin-top:2em}.ot-sdk-cookie-policy th{min-width:75px}.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy a:hover{background:#fff}.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}.ot-sdk-cookie-policy .ot-mobile-border{display:none}.ot-sdk-cookie-policy section{margin-bottom:2em}.ot-sdk-cookie-policy table{border-collapse:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy{font-family:inherit;font-size:1rem}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup{margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group-desc,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-table-header,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td{font-size:.9em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td a{font-size:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group{font-size:1em;margin-bottom:.6em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-title{margin-bottom:1.2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy>section{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th{min-width:75px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a:hover{background:#fff}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-mobile-border{display:none}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy section{margin-bottom:2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li{list-style:disc;margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li h4{display:inline-block}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table{border-collapse:inherit;margin:auto;border:1px solid #d7d7d7;border-radius:5px;border-spacing:initial;width:100%;overflow:hidden}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table td{border-bottom:1px solid #d7d7d7;border-right:1px solid #d7d7d7}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr:last-child td{border-bottom:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr th:last-child,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr td:last-child{border-right:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-host,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-cookies-type{width:25%}.ot-sdk-cookie-policy[dir=rtl]{text-align:left}#ot-sdk-cookie-policy h3{font-size:1.5em}@media only screen ...
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h5,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group {
#                         color: #696969;
#                     }
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title {
#                             color: #696969;
#                         }
#
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th {
#                             background-color: #F8F8F8;
#                         }
#
#             .ot-floating-button__front{background-image:url('https://cdn.cookielaw.org/logos/static/ot_persistent_cookie.png')}</style><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1035699132&amp;l=mtDataLayer"></script><script src="https://js.adsrvr.org/up_loader.1.1.0.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-S4EX53B760&amp;l=gaDataLayer"></script><script src="https://bat.bing.com/p/action/5320935.js" type="text/javascript" async="" data-ueto="ueto_74ff180ac7"></script><script type="text/javascript" async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1035699132/?random=1740948582043&amp;cv=11&amp;fst=1740948582043&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=45be52q0v898469414za200&amp;gcd=13t3t3t3t5l1&amp;dma=0&amp;tag_exp=101732282~101732284~102067808~102482433~102539968~102558064~102587591~102605417~102640600~102658453~102717422~102732003&amp;u_w=1280&amp;u_h=800&amp;url=https%3A%2F%2Fwww.ikea.com%2Fus%2Fen%2Fp%2Fhaegernaes-table-and-4-chairs-antique-stain-pine-70575947%2F&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=H%C3%84GERN%C3%84S%20table%20and%204%20chairs%2C%20antique%20stain%20pine%20-%20IKEA&amp;npa=0&amp;pscdl=noapi&amp;auid=515071285.1740948582&amp;uaa=arm&amp;uab=64&amp;uafvl=Not(A%253ABrand%3B99.0.0.0%7CGoogle%2520Chrome%3B133.0.6943.142%7CChromium%3B133.0.6943.142&amp;uamb=0&amp;uam=&amp;uap=macOS&amp;uapv=15.3.1&amp;uaw=0&amp;fledge=1&amp;data=event%3Dgtag.config&amp;rfmt=3&amp;fmt=4"></script><script type="text/javascript" async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1000557995/?random=1740948582063&amp;cv=11&amp;fst=1740948582063&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=45be52q0v898469414za200&amp;gcd=13t3t3t3t5l1&amp;dma=0&amp;tag_exp=101732282~101732284~102067808~102482433~102539968~102558064~102587591~102605417~102640600~102658453~102717422~102732003&amp;u_w=1280&amp;u_h=800&amp;url=https%3A%2F%2Fwww.ikea.com%2Fus%2Fen%2Fp%2Fhaegernaes-table-and-4-chairs-antique-stain-pine-70575947%2F&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=H%C3%84GERN%C3%84S%20table%20and%204%20chairs%2C%20antique%20stain%20pine%20-%20IKEA&amp;npa=0&amp;pscdl=noapi&amp;auid=515071285.1740948582&amp;uaa=arm&amp;uab=64&amp;uafvl=Not(A%253ABrand%3B99.0.0.0%7CGoogle%2520Chrome%3B133.0.6943.142%7CChromium%3B133.0.6943.142&amp;uamb=0&amp;uam=&amp;uap=macOS&amp;uapv=15.3.1&amp;uaw=0&amp;fledge=1&amp;data=event%3Dgtag.config&amp;rfmt=3&amp;fmt=4"></script><script type="text/javascript" async="" src="//t.contentsquare.net/uxa/ca5424847dbc1.js"></script><meta http-equiv="origin-trial" content=""></head><body data-version="v206" data-shopping-available="true" data-list-available="true"><!-- 2025-02-26T19:38:05.980Z, Navigera 5ce51d025d0731854912b87c7b31556c29961ab1 -->
#   <a href="#hnf-content" class="hnf-skip-to-content hnf-btn hnf-btn--secondary">
#     <span class="hnf-btn__inner">
#       <span class="hnf-btn__label">Skip to main content</span>
#     </span>
#   </a>
#
#       <div class="hnf-messages">
#
#
#         <div class="hnf-content-container hnf-utilities">
#           <div class="hnf-utilities__wrapper">
#             <div class="hnf-utilities__block hnf-utilities__block--localisation">
#               <div class="hnf-utilities__localisation-button" data-props="{&quot;languages&quot;:[{&quot;language&quot;:&quot;English&quot;,&quot;homeUrl&quot;:&quot;https://www.ikea.com/us/en/&quot;},{&quot;language&quot;:&quot;Español&quot;,&quot;homeUrl&quot;:&quot;https://www.ikea.com/us/es/&quot;}],&quot;ecomMarket&quot;:true,&quot;localeStrings&quot;:{&quot;LOCALISATION_CLOSE_MODAL&quot;:&quot;Close&quot;,&quot;LOCALISATION_CANCEL_MODAL&quot;:&quot;Cancel&quot;,&quot;LOCALISATION_SELECT_LANGUAGE&quot;:&quot;Select your preferred language&quot;,&quot;LOCALISATION_CURRENT_STORE_HEADING&quot;:&quot;You’re viewing the United States ikea.com&quot;,&quot;LOCALISATION_CHANGE_COUNTRY_LINK&quot;:&quot;Change country/region&quot;,&quot;LOCALISATION_CHANGE_COUNTRY_DISCLAIMER&quot;:&quot;Please be aware your shopping cart will be emptied if changed.&quot;},&quot;alignment&quot;:&quot;left&quot;}">
#                 <a href="#" class="hnf-link hnf-link--subtle hnf-link--white" aria-label="Change language or country/region, current language is English" aria-haspopup="dialog">
#                   <svg viewBox="0 0 24 24" focusable="false" width="24" height="24" aria-hidden="true" class="hnf-svg-icon hnf-btn__icon"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.7467 18.1766C12.9482 19.7737 12.2151 20 12 20c-.2151 0-.9482-.2263-1.7467-1.8234-.3065-.6131-.5745-1.3473-.7831-2.1766h5.0596c-.2086.8293-.4766 1.5635-.7831 2.1766zM14.8885 14h-5.777A17.7354 17.7354 0 0 1 9 12c0-.6949.0392-1.3641.1115-2h5.777c.0723.6359.1115 1.3051.1115 2 0 .6949-.0392 1.3641-.1115 2zm1.6955 2c-.2658 1.2166-.6492 2.307-1.1213 3.2138A8.0347 8.0347 0 0 0 18.9297 16H16.584zm3.164-2H16.9c.0656-.6462.1-1.3151.1-2 0-.6849-.0344-1.3538-.1-2h2.848A8.0156 8.0156 0 0 1 20 12a8.0156 8.0156 0 0 1-.252 2zm-.8183-6a8.035 8.035 0 0 0-3.467-3.2138c.4721.9068.8555 1.9972 1.1213 3.2138h2.3457zm-4.3999 0c-.2086-.8293-.4766-1.5635-.7831-2.1766C12.9482 4.2264 12.2151 4 12 4c-.2151 0-.9482.2263-1.7467 1.8234-.3065.613-.5745 1.3473-.7831 2.1766h5.0596zM7.416 8c.2658-1.2166.6491-2.307 1.1213-3.2138A8.035 8.035 0 0 0 5.0703 8H7.416zm-3.164 2A8.0147 8.0147 0 0 0 4 12c0 .6906.0875 1.3608.252 2H7.1a19.829 19.829 0 0 1-.1-2c0-.6849.0344-1.3538.1-2H4.252zm3.164 6H5.0704a8.0347 8.0347 0 0 0 3.467 3.2138C8.0651 18.307 7.6818 17.2166 7.4161 16zM22 12c0-5.5229-4.4772-10-10-10C6.4771 2 2 6.4771 2 12c0 5.5228 4.4771 10 10 10 5.5228 0 10-4.4772 10-10z"></path></svg>
#                   <span>EN</span>
#                   <span>US<span>English</span></span>
#                 </a>
#               </div>
#             </div>
#             <div class="hnf-utilities__block hnf-utilities__block--vp"><div class="hnf-vp" data-value-proposition-links=""><a class="hnf-link hnf-link--subtle hnf-link--white" href="https://www.ikea.com/us/en/customer-service/services/delivery/#18fc4069-0a57-11ec-912c-d5190c7baa2c" data-tracking-label="information"><svg focusable="false" width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="hnf-svg-icon " aria-hidden="true"><path fill-rule="evenodd" clip-rule="evenodd" d="M1 4h15v3h3.0246l3.9793 5.6848V18h-2.6567c-.4218 1.3056-1.6473 2.25-3.0933 2.25-1.446 0-2.6715-.9444-3.0932-2.25h-3.9044c-.4217 1.3056-1.6472 2.25-3.0932 2.25S4.4916 19.3056 4.0698 18H1V4zm3.0698 12c.4218-1.3056 1.6473-2.25 3.0933-2.25 1.446 0 2.6715.9444 3.0932 2.25H14V6H3v10h1.0698zM16 14.0007a3.24 3.24 0 0 1 1.2539-.2507c1.446 0 2.6715.9444 3.0933 2.25h.6567v-2.6848L17.9833 9H16v5.0007zM7.163 15.75c-.6903 0-1.25.5596-1.25 1.25s.5597 1.25 1.25 1.25c.6904 0 1.25-.5596 1.25-1.25s-.5596-1.25-1.25-1.25zm10.0909 0c-.6904 0-1.25.5596-1.25 1.25s.5596 1.25 1.25 1.25 1.25-.5596 1.25-1.25-.5596-1.25-1.25-1.25z" children="undefined"></path></svg><span class="hnf-vp__copy">Standard delivery starting at $19</span></a></div></div>
#             <div class="hnf-utilities__block hnf-utilities__block--pickers">
#                 <div id="hnf-header-postalcodepicker" data-props="{&quot;enableBeLuCountrySelection&quot;:false,&quot;enableStorePicker&quot;:true,&quot;enableHtmlGeoLocation&quot;:true,&quot;enableServerGeoLocation&quot;:true,&quot;serverGeolocationProvider&quot;:&quot;ipApiCom&quot;,&quot;disablePostalCodeNudge&quot;:false,&quot;requiresAdditionalData&quot;:true,&quot;localeStrings&quot;:{&quot;ENTER_POSTALCODE&quot;:&quot;Enter ZIP code&quot;,&quot;ENTER_YOUR_POSTALCODE&quot;:&quot;Use your location&quot;,&quot;ENTER_YOUR_POSTALCODE_DESC&quot;:&quot;Get updated information about product delivery and stock availability for your area.&quot;,&quot;POSTALCODE&quot;:&quot;Enter a Zip code&quot;,&quot;POSTALCODE_HELP&quot;:&quot;e.g. 19428&quot;,&quot;POSTALCODE_NOT_VALID_ERROR&quot;:&quot;The postal code you entered is not valid. Please try again.&quot;,&quot;POSTALCODE_EMPTY_FIELD&quot;:&quot;Please enter a Zip code.&quot;,&quot;STATE_CITY&quot;:&quot;Select state&quot;,&quot;STATE_CITY_CHOOSE&quot;:&quot;Choose an option&quot;,&quot;FIND_BY_DAUM&quot;:&quot;Find postal code&quot;,&quot;CONSENT&quot;:&quot;We use cookies to provide this service. Read more about how we use cookies in {{cookie policy link}}. Please note that your location won’t be shared.&quot;,&quot;CONSENT_OUR_POLICY&quot;:&quot;our policy&quot;,&quot;OPENS_NEW_WINDOW&quot;:&quot;Opens a new window&quot;,&quot;SELECT_COUNTRY&quot;:&quot;Select country&quot;,&quot;FORGET&quot;:&quot;Forget ZIP Code&quot;,&quot;USE&quot;:&quot;Save&quot;,&quot;CONFIRM_MESSAGE&quot;:&quot;You've selected {{postal code}} as your postcode&quot;,&quot;NUDGE_AUTOLOCATION_TEXT&quot;:&quot;Hej! Hope we got this right, otherwise please update your location.&quot;,&quot;NUDGE_GREETING&quot;:&quot;Hej!&quot;,&quot;NUDGE_TEXT&quot;:&quot;Add your ZIP code to see delivery information for products.&quot;,&quot;CLOSE_MODAL&quot;:&quot;Close&quot;}}">
#                   <a href="#" class="hnf-link hnf-link--subtle hnf-link--white hnf-utilities__postalcodepicker-button" role="button" aria-label="Enter ZIP code" aria-haspopup="dialog">
#                     <svg viewBox="0 0 24 24" focusable="false" width="24" height="24" aria-hidden="true" class="hnf-svg-icon"><path fill-rule="evenodd" clip-rule="evenodd" d="M1 4h15v3h3.0246l3.9793 5.6848V18h-2.6567c-.4218 1.3056-1.6473 2.25-3.0933 2.25-1.446 0-2.6715-.9444-3.0932-2.25h-3.9044c-.4217 1.3056-1.6472 2.25-3.0932 2.25S4.4916 19.3056 4.0698 18H1V4zm3.0698 12c.4218-1.3056 1.6473-2.25 3.0933-2.25 1.446 0 2.6715.9444 3.0932 2.25H14V6H3v10h1.0698zM16 14.0007a3.24 3.24 0 0 1 1.2539-.2507c1.446 0 2.6715.9444 3.0933 2.25h.6567v-2.6848L17.9833 9H16v5.0007zM7.163 15.75c-.6903 0-1.25.5596-1.25 1.25s.5597 1.25 1.25 1.25c.6904 0 1.25-.5596 1.25-1.25s-.5596-1.25-1.25-1.25zm10.0909 0c-.6904 0-1.25.5596-1.25 1.25s.5596 1.25 1.25 1.25 1.25-.5596 1.25-1.25-.5596-1.25-1.25-1.25z"></path></svg>
#                     <span class="hnf-utilities__value">Enter ZIP code</span>
#                   </a>
#                 </div>
#                 <div id="hnf-header-storepicker" data-props="{&quot;weekStartDay&quot;:&quot;MON&quot;,&quot;preSelectedStoreId&quot;:&quot;&quot;,&quot;messages&quot;:[],&quot;localeStrings&quot;:{&quot;SELECT_STORE_HEADING&quot;:&quot;Select store&quot;,&quot;SELECT_STORE_TEXT&quot;:&quot;Find your preferred store to learn about its opening hours, stock availability, and relevant offers.&quot;,&quot;SEARCH_PLACEHOLDER&quot;:&quot;Search by location&quot;,&quot;CURRENT_LOCATION&quot;:&quot;Use your current location&quot;,&quot;CURRENT_LOCATION_QUERY&quot;:&quot;Current location&quot;,&quot;CURRENT_LOCATION_FAIL_HEADING&quot;:&quot;Unable to locate you&quot;,&quot;CURRENT_LOCATION_FAIL_TEXT&quot;:&quot;Make sure you've allowed your browser to access your current location and try again.&quot;,&quot;STORES_SORTED_BY&quot;:&quot;Stores are sorted by distance to {{location}}&quot;,&quot;SEARCH_NO_HITS_HEADING&quot;:&quot;Location not found&quot;,&quot;SEARCH_NO_HITS_TEXT&quot;:&quot;Enter a valid location in your country/region and try again.&quot;,&quot;CLOSE_MODAL&quot;:&quot;Close&quot;,&quot;DISTANCE_AWAY&quot;:&quot;{{distance}} miles away&quot;,&quot;GET_DIRECTIONS&quot;:&quot;Get directions&quot;,&quot;VISIT_STORE_PAGE&quot;:&quot;Visit store page&quot;,&quot;TIMESPAN_FORMAT&quot;:&quot;{{from}} - {{to}}&quot;,&quot;SELECT_STORE&quot;:&quot;Select store&quot;,&quot;OPEN_TODAY&quot;:&quot;Open today {{from - to}}&quot;,&quot;OPEN_UNTIL&quot;:&quot;Open until {{closing time}}&quot;,&quot;OPEN_TOMORROW&quot;:&quot;Open tomorrow {{from - to}}&quot;,&quot;OPEN_24H&quot;:&quot;Open 24 hours&quot;,&quot;OPEN_TODAY_24H&quot;:&quot;Open 24 hours today&quot;,&quot;OPEN_TOMORROW_24H&quot;:&quot;Open 24 hours tomorrow&quot;,&quot;CHOOSE_DIFFERENT_STORE&quot;:&quot;Select a different store&quot;,&quot;WEEKDAY_MON&quot;:&quot;Mon&quot;,&quot;WEEKDAY_TUE&quot;:&quot;Tue&quot;,&quot;WEEKDAY_WED&quot;:&quot;Wed&quot;,&quot;WEEKDAY_THU&quot;:&quot;Thu&quot;,&quot;WEEKDAY_FRI&quot;:&quot;Fri&quot;,&quot;WEEKDAY_SAT&quot;:&quot;Sat&quot;,&quot;WEEKDAY_SUN&quot;:&quot;Sun&quot;,&quot;HOURS_CLOSED&quot;:&quot;Closed&quot;,&quot;HOURS_NORMAL&quot;:&quot;Normal opening hours&quot;,&quot;HOURS_DEVIATIONS&quot;:&quot;Exceptional opening hours&quot;}}">
#                   <a href="#" class="hnf-link hnf-link--white hnf-link--subtle hnf-utilities__storepicker-button" role="button" aria-label="Select store" aria-haspopup="dialog">
#                     <svg viewBox="0 0 24 24" focusable="false" width="24" height="24" aria-hidden="true" class="hnf-svg-icon"><path fill-rule="evenodd" clip-rule="evenodd" d="M2 4v16h20V4H2zm2 4V6h16v2H4zm0 2v8h3v-6h10v6h3v-8H4zm11 4h-2v4h2v-4zm-4 0H9v4h2v-4z"></path></svg>
#                     <span class="hnf-utilities__value">Select store</span>
#                   </a>
#                 </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#       <header class="hnf-header hnf-header--store hnf-header--postalcode hnf-header--nextnav">
#         <div class="hnf-content-container hnf-header__container hnf-page-container__main">
#           <div class="hnf-header__logo">
#             <a href="https://www.ikea.com/us/en/" class="hnf-link" data-tracking-label="ikea-logo" aria-label="IKEA Home">
#               <img src="https://www.ikea.com/global/assets/logos/brand/ikea.svg" alt="">
#             </a>
#           </div>
#             <div class="hnf-header__search">
#               <div data-css-scope="search-box" data-namespace="search-box" data-version="19af4ec048880f7db847ba521b5cd9a35b85487f" data-baseurl="https://www.ikea.com" data-locale="en-US">
#   <div data-id="box-mount" dir="ltr" class="notranslate"><form role="search" action="https://www.ikea.com/us/en/search/" class="search-box "><div class="search-wrapper"><div class="search-field"><svg width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" class="svg-icon search-field__search-icon search-field__search-icon--show"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.98 15.395a6.294 6.294 0 111.414-1.414l4.602 4.601-1.414 1.414-4.602-4.601zm.607-5.101a4.294 4.294 0 11-8.587 0 4.294 4.294 0 018.587 0z" fill="currentColor"></path></svg><span class="search-box__button-wrapper-close-icon"></span><input type="text" enterkeyhint="search" role="combobox" name="q" id="ikea-search-input" maxlength="150" aria-label="Search by product" aria-controls="search-suggestions" aria-expanded="false" aria-haspopup="false" placeholder="What are you looking for?" autocomplete="off" class="search-field__input" autocorrect="off" spellcheck="false"><span class="search-box__button-wrapper"><span class="search-box__button-wrapper-item"><div class="button-and-tooltip"><button id="search-box__visualsearch" aria-labelledby="search-box__visualsearch--tooltip" type="button" class="search-btn search-box__button single "><svg width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" class="svg-icon"><path fill-rule="evenodd" clip-rule="evenodd" d="M16.002 13a4 4 0 11-8 0 4 4 0 018 0zm-2 0a2 2 0 11-4 0 2 2 0 014 0z" fill="currentColor"></path><path fill-rule="evenodd" clip-rule="evenodd" d="M9.443 4L7.586 7H3v13h18V7h-4.586l-1.857-3H9.443zm1.114 2h2.886L15.3 9H19v9H5V9h3.7l1.857-3z" fill="currentColor"></path></svg></button><div role="tooltip" aria-hidden="true" id="search-box__visualsearch--tooltip" class="tooltip">Search IKEA products using a photo</div></div></span></span></div></div><a id="search-box-anchor" tabindex="-1" aria-hidden="true" class="sr-only">End of search dropdown.</a></form></div>
# </div>
#
#             </div>
#           <ul class="hnf-header__icons" data-shopping-links="">
#             <li class="hnf-header__search-btn">
#               <button type="button" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" aria-expanded="false" aria-label="Search">
#                 <span class="hnf-btn__inner">
#                   <svg viewBox="0 0 24 24" focusable="false" width="24" height="24" aria-hidden="true" class="hnf-svg-icon"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.9804 15.3946c-1.0361.7502-2.3099 1.1925-3.6869 1.1925C6.8177 16.5871 4 13.7694 4 10.2935 4 6.8177 6.8177 4 10.2935 4c3.4759 0 6.2936 2.8177 6.2936 6.2935 0 1.377-.4423 2.6508-1.1925 3.6869l4.6016 4.6016-1.4142 1.4142-4.6016-4.6016zm.6067-5.1011c0 2.3713-1.9223 4.2936-4.2936 4.2936C7.9223 14.5871 6 12.6648 6 10.2935 6 7.9223 7.9223 6 10.2935 6c2.3713 0 4.2936 1.9223 4.2936 4.2935z"></path></svg>
#                 </span>
#               </button>
#             </li>
#               <li id="hnf-header-profile" class="hnf-header__profile-link">
#                   <a href="https://www.ikea.com/us/en/profile/login/" class="hnf-btn hnf-btn--small hnf-leading-icon hnf-btn--tertiary hnf-header__profile-link__default" role="button" aria-haspopup="dialog" aria-hidden="false" rel="nofollow" data-tracking-label="profile" data-profile-link="">
#                     <span class="hnf-btn__inner">
# ...
#       <h-include-lazy src="https://www.ikea.com/us/en/header-footer/footer-lazy-fragment.html"></h-include-lazy>
#     </footer>
# <!-- 2025-02-26T19:38:05.979Z, Navigera 5ce51d025d0731854912b87c7b31556c29961ab1 -->
#     <script src="https://web-api.ikea.com/polyfills/v3/polyfill.min.js?features=IntersectionObserver%2CObject.freeze%2Cdefault%2Ces2015%2Ces2016%2Ces2017%2Ces2018%2Ces2019%2Cfetch&amp;flags=gated"></script>
#     <script id="nav-script-main" data-domain="www.ikea.com" data-site-folder="us/en" data-release="5ce51d025d0731854912b87c7b31556c29961ab1" data-sentry="true" data-other-langs="en,es" data-mv-agent="false" data-theme-enabled="false" data-theme-exclusion-paths="/planners\/smart-home/
#   /home-design/
#   /customer-service\/services\/finance-options/
#   /customer-service\/product-support\/recalls/
#   /campaigns\/join-new-movers-pubd0870e80/" src="https://www.ikea.com/us/en/header-footer/javascripts/main.cd1929b7fa6233513987.js" data-store-locator-path="https://www.ikea.com/us/en/header-footer/javascripts/storeLocator.e23013f0e4ff47b36b1f.js" data-gmak="AIzaSyB2YORk87PTvSlc6Lwua35nUqSd9WRh3Q0" data-ipacak="TKspzaHPz1gfGQB"></script>
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/localisationPicker.5cf37805d27d2a463f11.js"></script>
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/postalCodePicker.738a01a4da98bb3d3640.js"></script>
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/storePicker.081c0f8bab6bd2a3a779.js"></script>
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/tabsNavigation.30a0ffe575054d1e3289.js"></script>
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/mobileMenu.4ad32103d47d302f3c1f.js"></script>
#
#   <script src="https://www.ikea.com/us/en/header-footer/javascripts/bouncyFooter.4fea36950ca2c9e11037.js"></script>
#     <script type="text/javascript" src="https://accounts.ikea.com/resources/cie-utils/cie-utils-fragment.js"></script>
# <script type="text/javascript" src="https://www.ikea.com/us/en/token-service/token-service-e79980eaf70a265739a2.js"></script>
#     <script defer="defer" src="https://www.ikea.com/us/en/analytics/scripts/incognito.43003061.js" async=""></script><script>window.isLandingPage =
#     document.referrer.split('/')[2] !== location.host ? true : false;
#   window.analyticsQueue = window.analyticsQueue || [];
#   window.analyticsIncognitoQueue = window.analyticsIncognitoQueue || [];
#   window.sendEvent = function (evt) {
#     window.analyticsQueue.push(evt);
#     window.analyticsIncognitoQueue.push(evt);
#     const event = new CustomEvent('incognitoEvent', { detail: { ...evt } });
#     window.dispatchEvent(event);
#   };
#   window.ikea.analytics = {};
#   window.ikea.analytics.observeProducts = [];
#   window.ikea.analytics.observeProductDetails = [];
#   window.ikea.analytics.persisted = {};
#   window.ikea.analytics.persist = function (dimensions) {
#     Object.assign(window.ikea.analytics.persisted, dimensions);
#   };</script>
#
#
# <!-- Search Box Scripts: 2025-02-28 10:45:12 CET 19af4ec048880f7db847ba521b5cd9a35b85487f -->
# <script type="module" crossorigin="" src="https://www.ikea.com/us/en/search/box.677fb7f8.js"></script>
#
#
# <!-- /Search Box Scripts -->
#
#     <!-- RecommendationsScript: version: 64f0c61f4b68ec3e52cc749b441be4c6c5104b34, site-folder: us/en --><script>if (window && window.ikea && window.ikea.sentry && window.ikea.sentry.register) {
#     window.ikea.sentry.register('5583489', '10bb11cc3ff548e295b5e960579d8042', 'recommendations', '64f0c61f4b68ec3e52cc749b441be4c6c5104b34' || 'Unknown', 0.1, [/\/[a-z0-9]{2}\/[a-z0-9]{2}\/recommendations\/panels\//]);
#   }</script><script defer="defer" type="module" src="https://www.ikea.com/us/en/recommendations/panels/runtime.bb55bb72.js"></script><script defer="defer" type="module" src="https://www.ikea.com/us/en/recommendations/panels/main.bb55bb72.js"></script><!-- /RecommendationsScript -->
#     <!-- Favs-agent -->
# <div>
#     <div id="favs-add-to-list"></div>
#     <div id="favs-remove-from-list"></div>
#     <script type="module" async="" defer="" src="https://www.ikea.com/us/en/favs-agent/agent/agent-v1-56-0.feb2cb5f.js"></script>
# </div>
# <!-- End of Favs-agent -->
#
#     <script type="module" crossorigin="" src="https://www.ikea.com/us/en/shoppingcart/agent/agent-2-0-42.CcapJbo0.js"></script>
# <!-- Cart-agent -->
# <div id="cart-agent"></div>
# <div id="flexi-cart" translate="no"></div>
# <!-- End of Cart-agent -->
#
#     <!-- igift-agent: 1.15.1 - us/en -->
# <script src="//www.ikea.com/us/en/gift-registry/agent/agent.DMVkwsIC.js" async="" defer=""></script>
#     <link rel="stylesheet" href="https://www.ikea.com/us/en/content-rec/fragments/static/initer.dd3ed133.css" data-initer=""><script async="" defer="" type="module" src="https://www.ikea.com/us/en/content-rec/fragments/static/initer.dd3ed133.js" data-initer=""></script>
#     <script>
# if (window && window.ikea && window.ikea.sentry && window.ikea.sentry.register) {
#     window.ikea.sentry.register(
#       '5244394', // The Sentry project ID
#       '4def75a18cb34ab59e68a690be123979', // The Sentry project key
#       'feed', // The product name
#       '20250302T005107-b33dde84', // The product release version
#       0.1, // 10% sample rate
#       [/\/[a-z0-9]{2}\/[a-z0-9]{2}\/insp-feed\/content-gallery-app\//] // Paths to register for errors in
#     );
#   }
# </script>
# <script async="" src="https://www.ikea.com/us/en/insp-feed/content-gallery-app/feed.e4d2f261.js"></script>
#
#     <script src="https://www.ikea.com/us/en/loyalty/loyalty-modal.222ee6.js" type="text/javascript"></script>
#     <script type="module" src="https://www.ikea.com/us/en/nudge/main.DMscUfcx.js"></script>
#     <script async="" type="module" class="optanon-category-1" src="https://www.ikea.com/us/en/isx-billie-widget/assets/index-ByrzAZBu.js"></script>
#     <script id="nav-script-instantpage" type="module" src="https://www.ikea.com/us/en/header-footer/javascripts/instantpage.822886b611c1bd74fee3.js"></script>
# <div id="js-is-mobile" class="is-mobile"></div><script type="application/json" id="range__page-meta-data">{"correctUrl":"/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/"}</script><!-- Range PIP app - Version:v206 -->
#   <script src="https://www.ikea.com/us/en/products/javascripts/pip-main.4771acabe0c8d03f9ef3.js"></script><span></span><script type="application/ld+json" id="pip-range-json-ld">{"@context":"https://schema.org/","@type":"Product","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.7","reviewCount":"97"},"brand":{"@type":"Brand","name":"IKEA"},"description":"HÄGERNÄS Table and 4 chairs - antique stain pine. Easy to bring home since the whole dining set is packed in one box. This sturdy dining set with a table and four chairs is perfect for your breakfast nook or smaller dining area. Seats 4. Recommended for indoor use only.","image":["https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1350925_pe951817_s5.jpg","https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1376866_pe960596_s5.jpg","https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1376865_pe960597_s5.jpg","https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1376693_pe960469_s5.jpg","https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1290239_pe934615_s5.jpg","https://www.ikea.com/us/en/images/products/haegernaes-table-and-4-chairs-antique-stain-pine__1374234_pe960096_s5.jpg"],"mpn":"705.759.47","name":"HÄGERNÄS Table and 4 chairs - antique stain pine","offers":{"@type":"Offer","availability":"https://schema.org/InStock","itemCondition":"https://schema.org/NewCondition","price":"199.99","priceCurrency":"USD","seller":{"@type":"Organization","name":"IKEA"},"url":"https://www.ikea.com/us/en/p/haegernaes-table-and-4-chairs-antique-stain-pine-70575947/"},"review":[{"@type":"Review","author":{"@type":"Person","name":"Erica"},"name":"Low quality ","reviewBody":"The wood is very soft so it gets dings and scratches crazy easy. The stain is also very thin so it doesn't seem like it will protect the table well over time.\n\nThe \"screws\" to attach the legs are HORRIBLE. I have no idea why they went with that option. They kept coming undone as I was putting it together and now I'm worried the legs won't stay on","reviewRating":{"@type":"Rating","ratingValue":2}},{"@type":"Review","author":{"@type":"Person","name":"July"},"name":"Buy it!","reviewBody":"If you’re on a budget but need something sturdy this is perfect. My husband is 6’1 and the table is perfect for him too.","reviewRating":{"@type":"Rating","ratingValue":5}},{"@type":"Review","author":{"@type":"Person","name":"Jawun"},"name":"Amazing ","reviewBody":"This set is everything I wanted. ","reviewRating":{"@type":"Rating","ratingValue":5}},{"@type":"Review","author":{"@type":"Person","name":"Cecilia"},"name":"Love it ","reviewBody":"Nice and sturdy table that's easy to build and looks so nice. ","reviewRating":{"@type":"Rating","ratingValue":5}},{"@type":"Review","author":{"@type":"Person","name":"J"},"name":"Need PreDrilled Holes for Chair Seats","reviewBody":"It is difficult to put 16 screws into the four seats of the chairs without predrilled holes.\n An electric drill would have been extremely helpful. Longer and stronger tools that provide better leverage would have also been helpful. My efforts with pressure turning of screws without predrilled holes resulted in stripped screw effects when the wood-like material of the seat split. Same stripped screw effect occurred when weight-lifting, strong-hand friends attempted to pressure-turn screws into nonexistent holes in seat of chair. The project was only completed when my husband arrived with decades of model making experience \u0026 adeptness in utilizing the difficult-to-use out-of-the-box tools. Exhaustingly difficult for an average person like myself to complete without predrilled holes to screw in the seats. ","reviewRating":{"@type":"Rating","ratingValue":4}},{"@type":"Review","author":{"@type":"Person","name":"Lizbeth"},"name":"Perfect!","reviewBody":"Eas ...
# <link rel="modulepreload" crossorigin="" href="https://www.ikea.com/global/assets/rotera/preact-CJVjw7Ab.js">
# <link rel="stylesheet" href="https://www.ikea.com/us/en/user-generated-content/rr-pip/app/rr-pip.66558af5.bundle.css"><link rel="stylesheet" href="https://www.ikea.com/us/en/ugc/ratings-reviews/leave-review/fragments/rr-leave-review.bundle-ed3171e8.css"><script type="module" src="https://www.ikea.com/us/en/user-generated-content/rr-pip/app/rr-pip.66558af5.bundle.js"></script><script src="https://www.ikea.com/us/en/ugc/ratings-reviews/leave-review/fragments/rr-leave-review.bundle-ed3171e8.js" type="module"></script>
# <!-- Attract refs/tags/v0.0.40 -->
# <div class="ao-page-container">
#   <div id="ao-app"></div>
#   <script type="module" defer="" src="https://www.ikea.com/us/en/customer-service/services/apply-for-finance/fragments/monthlyfragmentsnew/main-DGGgadux.js"></script>
# </div>
# <!-- End of Attract -->
# <!-- 2025-02-26T19:38:05.980Z, Navigera 5ce51d025d0731854912b87c7b31556c29961ab1 -->
#     <script async="" type="module" crossorigin="" src="https://www.ikea.com/us/en/local-modules/igift-us-pip-module/assets/index-DYzfI0V1.js"></script><link rel="stylesheet" crossorigin="" href="https://www.ikea.com/us/en/local-modules/igift-us-pip-module/assets/index-JFGHPrSt.css"><script type="text/plain" src="https://connect.breadpayments.com/unified.sdk.js" data-bread-payments-key="207a9970-167f-43ac-b99e-c10ce22baa85" async=""></script><script async="" type="module" crossorigin="" src="https://www.ikea.com/us/en/local-modules/us-pulse-insight/assets/index-DR4DwAcy.js"></script>
#   <script src="https://www.ikea.com/us/en/marketing-tags/scripts/mt-script-loader.b982de2b.js" type="text/javascript" defer=""></script>
#
# <!-- Tack Ingvar --><script type="text/javascript" src="/DBoSRze_0w2U9D40Kw/iOYESJEEiLXfkuNY/AXBCTA/LRtLOh/4JVlw"></script><div id="nudge_root"></div><div id="tugc-leave-review-frontend-mount-point"><div tabindex="-1" class="rr-leave-review-modal-wrapper rr-leave-review-modal-wrapper--close rr-leave-review-modal-container"><div class="rr-leave-review-modal-wrapper__backdrop rr-leave-review-modal-wrapper__backdrop--dark"></div></div><div tabindex="-1" class="rr-leave-review-modal-wrapper rr-leave-review-modal-wrapper--close rr-leave-review-message-container"><div class="rr-leave-review-modal-wrapper__backdrop rr-leave-review-modal-wrapper__backdrop--dark"></div></div></div><iframe src="https://a11701662245.cdn-pci.optimizely.com/client_storage/a11701662245.html" hidden="" tabindex="-1" title="Optimizely Internal Frame" height="0" width="0" style="display: none;"></iframe><div id="tugc-rr-pip-frontend-mount-point"><div><div tabindex="-1" class="ugc-rr-pip-fe-modal-wrapper ugc-rr-pip-fe-modal-wrapper--close"><div class="ugc-rr-pip-fe-modal-wrapper__backdrop ugc-rr-pip-fe-modal-wrapper__backdrop--dark"></div></div><div tabindex="-1" class="ugc-rr-pip-fe-modal-wrapper ugc-rr-pip-fe-modal-wrapper--close"><div class="ugc-rr-pip-fe-modal-wrapper__backdrop ugc-rr-pip-fe-modal-wrapper__backdrop--dark"></div></div><div tabindex="-1" class="ugc-rr-pip-fe-modal-wrapper ugc-rr-pip-fe-modal-wrapper--close"><div class="ugc-rr-pip-fe-modal-wrapper__backdrop ugc-rr-pip-fe-modal-wrapper__backdrop--dark"></div></div><div tabindex="-1" class="ugc-rr-pip-fe-modal-wrapper ugc-rr-pip-fe-modal-wrapper--close"><div class="ugc-rr-pip-fe-modal-wrapper__backdrop ugc-rr-pip-fe-modal-wrapper__backdrop--dark"></div></div><div tabindex="-1" class="ugc-rr-pip-fe-modal-wrapper ugc-rr-pip-fe-modal-wrapper--close"><div class="ugc-rr-pip-fe-modal-wrapper__backdrop ugc-rr-pip-fe-modal-wrapper__backdrop--dark"></div></div></div></div><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/sentry.8b98d30f.js"></script><div class="rec-add-to-cart-modal"><div data-custom-compact="{&quot;source&quot;:&quot;rec-add-to-cart&quot;}" data-test-id="a2c-modal-testid" tabindex="-1" class="rec-modal-wrapper rec-modal-wrapper--close"><div class="rec-modal-wrapper__backdrop rec-modal-wrapper__backdrop--dark"></div></div></div><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/adform-local.92387887.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/amazon.d1b43b6c.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/bing.1e82d9ff.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/claritas.a033bb0e.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/foursquare.34263dff.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/google-tags.c4229db7.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/jivox.c6a1c545.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/pinterest-local.85ac25a2.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/tradedesk.09dd98a1.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/yahoo-dot.341177ef.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/reddit.08a323ed.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/meta-local.2f086a35.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/tvsquared.47775549.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/adform-global.19c01d57.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/meta-global.90afae1b.js"></script><script defer="" src="https://www.ikea.com/us/en/marketing-tags/scripts/pinterest-global.63739649.js"></scr ...

# %%
import time
import json
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# ✅ Load dataset
df = pd.read_csv("ikea_final_data.csv")

# ✅ Filter rows where product names are missing
missing_names = df[df["Product Name"].isnull()]

# ✅ Set up Selenium (Headless Chrome)
chrome_options = Options()
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--disable-dev-shm-usage")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# ✅ Function to scrape product names from JSON-LD
def get_product_name(url):
    try:
        print(f"🔄 Fetching: {url}")
        driver.get(url)
        time.sleep(5)  # Wait for page to fully load

        # ✅ Find JSON-LD script with product details
        script_tag = driver.find_element(By.ID, "pip-range-json-ld")
        json_data = json.loads(script_tag.get_attribute("innerText"))

        # ✅ Extract product name
        product_name = json_data.get("name", "N/A")
        print(f"✅ Product Name Found: {product_name}")
        return product_name
    except Exception as e:
        print(f"❌ Failed to get name for {url}: {e}")
        return None

# ✅ Scrape missing product names
for index, row in missing_names.iterrows():
    product_name = get_product_name(row["Link"])
    if product_name:
        df.at[index, "Product Name"] = product_name
    time.sleep(3)  # Prevent blocking

# ✅ Close Selenium
driver.quit()

# ✅ Save updated dataset
df.to_csv("ikea_final_fixed.csv", index=False)
print("✅ Missing product names scraped and saved as ikea_final_fixed.csv")
